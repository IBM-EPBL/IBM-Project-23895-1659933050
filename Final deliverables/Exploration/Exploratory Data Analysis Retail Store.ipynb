# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
import os
os.chdir("C:/Users/Pradeep/Desktop/DataSets")

# %%
df=pd.read_csv('inventory_data_total(AutoRecovered).csv')

# %%
df
# Out:
#      data(Year)  Month  venda(Sales)  estoque(Stock)  preco(Price)  Revenue
# 0    01-01-2014      1             0            4972          1.29     0.00
# 1    02-01-2014      1            70            4902          1.29    90.30
# 2    03-01-2014      1            59            4843          1.29    76.11
# 3    04-01-2014      1            93            4750          1.29   119.97
# 4    05-01-2014      1            96            4654          1.29   123.84
# ..          ...    ...           ...             ...           ...      ...
# 932  27-07-2016      7            98            3179          2.39   234.22
# 933  28-07-2016      7           108            3071          2.39   258.12
# 934  29-07-2016      7           128            4095          2.39   305.92
# 935  30-07-2016      7           270            3825          2.39   645.30
# 936  31-07-2016      7           183            3642          2.39   437.37
#
# [937 rows x 6 columns]

# %%
df.describe()
# Out:
#             Month  venda(Sales)  estoque(Stock)  preco(Price)     Revenue
# count  937.000000    937.000000      937.000000    937.000000  937.000000
# mean     5.975454     90.533618     1608.258271      1.592572  148.226083
# std      3.349390     80.682089     1356.691877      0.529502  144.298915
# min      1.000000      0.000000        0.000000      0.000000    0.000000
# 25%      3.000000     33.000000      794.000000      1.290000   52.320000
# 50%      6.000000     76.000000     1348.000000      1.390000  112.230000
# 75%      9.000000    127.000000     1964.000000      1.890000  207.100000
# max     12.000000    542.000000     7228.000000      2.980000  870.240000

# %%
df.isnull().sum()
# Out:
# data(Year)        0
# Month             0
# venda(Sales)      0
# estoque(Stock)    0
# preco(Price)      0
# Revenue           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['data(Year)', 'Month', 'venda(Sales)', 'estoque(Stock)', 'preco(Price)',
#        'Revenue'],
#       dtype='object')

# %%
df.corr()
# Out:
#                    Month  venda(Sales)  estoque(Stock)  preco(Price)   Revenue
# Month           1.000000     -0.020992       -0.364307     -0.062187 -0.021615
# venda(Sales)   -0.020992      1.000000        0.153659      0.094779  0.912127
# estoque(Stock) -0.364307      0.153659        1.000000     -0.032604  0.151113
# preco(Price)   -0.062187      0.094779       -0.032604      1.000000  0.399306
# Revenue        -0.021615      0.912127        0.151113      0.399306  1.000000

# %%
df.columns
# Out:
# Index(['data(Year)', 'Month', 'venda(Sales)', 'estoque(Stock)', 'preco(Price)',
#        'Revenue'],
#       dtype='object')

# %%
df.shape
# Out:
# (937, 6)

# %%
sns.heatmap(df.corr(),annot=True)
plt.title("Correlation Matrix")
plt.show()

# %%
df['preco(Price)'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
df['venda(Sales)'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
df['Month'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column='Revenue')
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column='Month')
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column='venda(Sales)')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df, x_vars=['Revenue','preco(Price)','estoque(Stock)'], y_vars='venda(Sales)', height = 4)

# %%
sns.displot(df['preco(Price)'])

# %%
sns.distplot(df['venda(Sales)'], fit=stats.norm)
# Out:
# C:\Users\Pradeep\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='venda(Sales)', ylabel='Density'>
